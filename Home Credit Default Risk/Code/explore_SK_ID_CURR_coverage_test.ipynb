# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5538b4cd-387f-43f6-8896-67fbf2aa9da8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5538b4cd-387f-43f6-8896-67fbf2aa9da8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"oliverli0414","key":"19df8e5218b8495a8c1ea362134c4a27"}'}

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle competitions download -c home-credit-default-risk
# !unzip home-credit-default-risk.zip
# Out:
# ...
# 100% 688M/688M [00:12<00:00, 92.5MB/s]
# 100% 688M/688M [00:12<00:00, 56.2MB/s]
# Archive:  home-credit-default-risk.zip
#   inflating: HomeCredit_columns_description.csv
#   inflating: POS_CASH_balance.csv
#   inflating: application_test.csv
#   inflating: application_train.csv
#   inflating: bureau.csv
#   inflating: bureau_balance.csv
#   inflating: credit_card_balance.csv
#   inflating: installments_payments.csv
#   inflating: previous_application.csv
#   inflating: sample_submission.csv

# %%
import pandas as pd
import numpy as np

# %%
bureau = pd.read_csv('bureau.csv')[['SK_ID_BUREAU','SK_ID_CURR']]
bureau_balance = pd.read_csv('bureau_balance.csv')[['SK_ID_BUREAU']]
application_test = pd.read_csv('application_test.csv')[['SK_ID_CURR']]

# %%
bureau_merge = bureau_balance.merge(bureau, on='SK_ID_BUREAU',how='inner').drop_duplicates()

# %%
print(bureau['SK_ID_BUREAU'].nunique())
print(bureau_balance['SK_ID_BUREAU'].nunique())
print(bureau_merge['SK_ID_BUREAU'].nunique())
print(bureau['SK_ID_CURR'].nunique())
print(bureau_merge['SK_ID_CURR'].nunique())
# Out:
# 1716428
# 817395
# 774354
# 305811
# 134542

# %%
bureau_merge__application_test = bureau_merge.merge(application_test, on='SK_ID_CURR', how='inner').drop_duplicates()
print(bureau_merge__application_test['SK_ID_CURR'].nunique())
print(bureau_merge['SK_ID_CURR'].nunique())
print(application_test['SK_ID_CURR'].nunique())
# Out:
# 42311
# 134542
# 48744

# %%
bureau__application_test = bureau.merge(application_test, on='SK_ID_CURR', how='inner').drop_duplicates()
print(bureau__application_test['SK_ID_CURR'].nunique())
print(bureau['SK_ID_CURR'].nunique())
print(application_test['SK_ID_CURR'].nunique())
# Out:
# 42320
# 305811
# 48744

# %%
POS_CASH_balance = pd.read_csv('POS_CASH_balance.csv')[['SK_ID_CURR']]
POS_CASH_balance__application_test = POS_CASH_balance.merge(application_test, on='SK_ID_CURR', how='inner').drop_duplicates()
print(POS_CASH_balance__application_test['SK_ID_CURR'].nunique())
print(POS_CASH_balance['SK_ID_CURR'].nunique())
print(application_test['SK_ID_CURR'].nunique())
# Out:
# 47808
# 337252
# 48744

# %%
credit_card_balance = pd.read_csv('credit_card_balance.csv')[['SK_ID_CURR']]
credit_card_balance__application_test = credit_card_balance.merge(application_test, on='SK_ID_CURR', how='inner').drop_duplicates()
print(credit_card_balance__application_test['SK_ID_CURR'].nunique())
print(credit_card_balance['SK_ID_CURR'].nunique())
print(application_test['SK_ID_CURR'].nunique())
# Out:
# 16653
# 103558
# 48744

# %%
previous_application = pd.read_csv('previous_application.csv')[['SK_ID_CURR']]
previous_application__application_test = previous_application.merge(application_test, on='SK_ID_CURR', how='inner').drop_duplicates()
print(previous_application__application_test['SK_ID_CURR'].nunique())
print(previous_application['SK_ID_CURR'].nunique())
print(application_test['SK_ID_CURR'].nunique())
# Out:
# 47800
# 338857
# 48744

# %%
installments_payments = pd.read_csv('installments_payments.csv')[['SK_ID_CURR']]
installments_payments__application_test = installments_payments.merge(application_test, on='SK_ID_CURR', how='inner').drop_duplicates()
print(installments_payments__application_test['SK_ID_CURR'].nunique())
print(installments_payments['SK_ID_CURR'].nunique())
print(application_test['SK_ID_CURR'].nunique())
# Out:
# 47944
# 339587
# 48744

# %%
n = application_test['SK_ID_CURR'].nunique()
print('Dataset','No. of training SK_ID_CURR contained','Coverage %')
print('application_test.csv',n,'NA')
print('bureau.csv',bureau__application_test['SK_ID_CURR'].nunique(),str(round(bureau__application_test['SK_ID_CURR'].nunique()/n*100))+'%')
print('bureau_balance.csv',bureau_merge__application_test['SK_ID_CURR'].nunique(),str(round(bureau_merge__application_test['SK_ID_CURR'].nunique()/n*100))+'%')
print('POS_CASH_balance.csv',POS_CASH_balance__application_test['SK_ID_CURR'].nunique(),str(round(POS_CASH_balance__application_test['SK_ID_CURR'].nunique()/n*100))+'%')
print('credit_card_balance.csv',credit_card_balance__application_test['SK_ID_CURR'].nunique(),str(round(credit_card_balance__application_test['SK_ID_CURR'].nunique()/n*100))+'%')
print('previous_application.csv',previous_application__application_test['SK_ID_CURR'].nunique(),str(round(previous_application__application_test['SK_ID_CURR'].nunique()/n*100))+'%')
print('installments_payments.csv',installments_payments__application_test['SK_ID_CURR'].nunique(),str(round(installments_payments__application_test['SK_ID_CURR'].nunique()/n*100))+'%')
# Out:
# Dataset No. of training SK_ID_CURR contained Coverage %
# application_test.csv 48744 NA
# bureau.csv 42320 87%
# bureau_balance.csv 42311 87%
# POS_CASH_balance.csv 47808 98%
# credit_card_balance.csv 16653 34%
# previous_application.csv 47800 98%
# installments_payments.csv 47944 98%
